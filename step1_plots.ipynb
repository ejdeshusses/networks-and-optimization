# testing grid data:    0  1   2
# 0  2  2  85
# 1  2  2  82
# 2  2  2  85
# 3  2  2  84
# 4  2  2  85
# testing netgen data:    0  1   2
# 0  2  2  40
# 1  2  2   2
# 2  2  2  46
# 3  2  2  55
# 4  2  2  52

# %%
#######################################

import numpy as np
import matplotlib.pyplot as plt

area = 40
color = '#9eb23b'
colorB = '#4cacbc'
fig, ax = plt.subplots(figsize=(8,6))

flows = ax.scatter(net_df[0], net_df[2], label='NetGen Maxflows',  s=area, c=color)
flows = ax.scatter(grids_df[0], grids_df[2], label='Grid Maxflows',  s=area, c=colorB)


font_size = 15

plt.legend(fontsize=font_size-5)


# Add axis labels and title
plt.xlabel('n ', fontsize=font_size)
plt.ylabel('Max Flow (unit)', fontsize=font_size)
plt.title('Maxflow for 10 replications of n=2,...,8')


# plt.xticks(0, 1)
plt.yticks(fontsize=font_size)
plt.xticks(fontsize=font_size-4)
plt.ylim(0, 200)
# plt.legend(loc='upper center',label='range, mean', fontsize=16)

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

area = 40
color = '#9eb23b'
colorB = '#4cacbc'
fig, ax = plt.subplots(figsize=(8,6))

flows = ax.scatter(net_df[1], net_df[2], label='NetGen Maxflows',  s=area, c=color)
flows = ax.scatter(grids_df[1], grids_df[2], label='Grid Maxflows',  s=area, c=colorB)


font_size = 15

plt.legend(fontsize=font_size-5)

# Add axis labels and title
plt.xlabel('Density (edges per node)', fontsize=font_size)
plt.ylabel('Max Flow (unit)', fontsize=font_size)
plt.title('Maxflow for 10 replications of n=2,...,8')


# plt.xticks(0, 1)
plt.yticks(fontsize=font_size)
plt.xticks(fontsize=font_size-4)
plt.ylim(0, 200)
# plt.legend(loc='upper center',label='range, mean', fontsize=16)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a figure with two horizontally stacked subplots
fig, axs = plt.subplots(1, 2)
fig.suptitle('Max flow per n in Grid Networks')

# Plot the scatter plot in the first subplot
axs[0].scatter(grids_df[0], grids_df[2], c='b', label='Grids Max Flows')
axs[0].set_title('Grids')
axs[0].set_xlabel('n')
axs[0].set_ylabel('Maxflow')

# Plot the scatter plot in the second subplot
axs[1].scatter(net_df[0], net_df[2], c='r', label='Netgen Max Flows')
axs[1].set_title('Netgen')
axs[1].set_xlabel('n')
axs[1].set_ylabel('Maxflow')

# Add a legend
for ax in axs:
    ax.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a figure with two horizontally stacked subplots
fig, axs = plt.subplots(1, 2)
fig.suptitle('Max flow per densities in Grid Networks')

# Plot the scatter plot in the first subplot
axs[0].scatter(grids_df[1], grids_df[2], c='b', label='Grids Max Flows')
axs[0].set_title('Grids')
axs[0].set_xlabel('Density')
axs[0].set_ylabel('Maxflow')

# Plot the scatter plot in the second subplot
axs[1].scatter(net_df[1], net_df[2], c='r', label='Netgen Max Flows')
axs[1].set_title('Netgen')
axs[1].set_xlabel('Density')
axs[1].set_ylabel('Maxflow')

# Add a legend
for ax in axs:
    ax.legend()

# Show the plot
plt.show()
